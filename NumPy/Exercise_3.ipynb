# %%
import numpy as np

daily_sales = np.array([
    [10, 15, 8, 12],   # Headphones
    [5, 7, 4, 6],      # Smartwatches
    [2, 3, 2, 4]       # Speakers
])

# %%
smartwatch_sales = daily_sales[1]
print(smartwatch_sales)
# Out:
# [5 7 4 6]

# %%
first_two_days = daily_sales[:, :2]
print(first_two_days)
# Out:
# [[10 15]
#  [ 5  7]
#  [ 2  3]]

# %%
speakers_thursday = daily_sales[2][3]
print(speakers_thursday)
# Out:
# 4

# %%
sub_array = daily_sales[0:2, 0:2]
print(sub_array)
# Out:
# [[10 15]
#  [ 5  7]]
