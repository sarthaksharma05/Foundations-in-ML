# %%
import numpy as np

# Marks array (5 students × 3 subjects)
marks = np.array([
    [78, 85, 90],
    [45, 60, 55],
    [88, 92, 95],
    [30, 40, 45],
    [65, 70, 75]
])

print(marks)
# Out:
# [[78 85 90]
#  [45 60 55]
#  [88 92 95]
#  [30 40 45]
#  [65 70 75]]

# %%
print(marks.shape)
# Out:
# (5, 3)

# %%
print(marks.size)
# Out:
# 15

# %%
print(marks.dtype)
# Out:
# int64

# %%
print(marks[1])
# Out:
# [45 60 55]

# %%
print(marks[:, 2])
# Out:
# [90 55 95 45 75]

# %%
print(marks[0, 1])
# Out:
# 85
